# %%
import cv2
import numpy as np
import face_recognition
import os
from datetime import datetime

from tkinter import *
from tkinter import messagebox as mb
import json

import cv2
import numpy as np
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import time



import cv2
import numpy as np
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import time

# %%
# from PIL import ImageGrab

path = 'c:/Users/Saicharan/MY PROJECTS/IEDC/Training_images'
images = []
classNames = []
myList = os.listdir(path)
print(myList)
for cl in myList:
    curImg = cv2.imread(f'{path}/{cl}')
    images.append(curImg)
    classNames.append(os.path.splitext(cl)[0])
print(classNames)
# Out:
# ['Manish.jpg', 'praneeth.jpeg', 'Rohith.JPG', 'Sonu.png']
# ['Manish', 'praneeth', 'Rohith', 'Sonu']

# %%
def findEncodings(images):
    encodeList = []


    for img in images:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        encode = face_recognition.face_encodings(img)[0]
        encodeList.append(encode)
    return encodeList

encodeListKnown = findEncodings(images)

print('Encoding Complete')

type(encodeListKnown)
# Out:
# Encoding Complete
# list

# %%
check = []
def recognize():
    cap = cv2.VideoCapture(0)

    for i in range(15):
        success, img = cap.read()
    # img = captureScreen()
        imgS = cv2.resize(img, (0, 0), None, 0.25, 0.25)
        imgS = cv2.cvtColor(imgS, cv2.COLOR_BGR2RGB)

        facesCurFrame = face_recognition.face_locations(imgS)
        encodesCurFrame = face_recognition.face_encodings(imgS, facesCurFrame)

        for encodeFace, faceLoc in zip(encodesCurFrame, facesCurFrame):
            matches = face_recognition.compare_faces(encodeListKnown, encodeFace)
            faceDis = face_recognition.face_distance(encodeListKnown, encodeFace)
    # print(faceDis)
            matchIndex = np.argmin(faceDis)

            if matches[matchIndex]:
                name = classNames[matchIndex].upper()
                print(name)
                check.append(name)
                y1, x2, y2, x1 = faceLoc
                y1, x2, y2, x1 = y1 * 4, x2 * 4, y2 * 4, x1 * 4
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.rectangle(img, (x1, y2 - 35), (x2, y2), (0, 255, 0), cv2.FILLED)
                cv2.putText(img, name, (x1 + 6, y2 - 6), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2)
        cv2.imshow('img',img)        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cv2.destroyAllWindows()
    cap.release()

# %%
recognize()
# Out:
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU
# SONU

# %%
def checking():
    print(check)
    try:
        name = max(check,key=check.count)
        print(name,'is Verified')
        return name
    except:
        pass

# %%
auth = checking()
# Out:
# ['SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU', 'SONU']
# SONU is Verified

# %%
if (auth != None):
    print("Authentication Successfull for ",auth)
    import cv2
    import numpy as np
    from sklearn.metrics import accuracy_score
    import matplotlib.pyplot as plt
    import time

    # DYNAMIC INPUT OF QUESTIONS

    options = []
    q_a = dict()
    questions = []
    answers = []
    def Test():
        yes = int(input("Do you want to create new test ? \n\n   Enter 1 for yes:  "))

        if yes ==1:
            n = int(input("Enter Number Of Questions:  "))
            for i in range(n):
                question = input("Enter The Question:  ")
                questions.append(question)
                for i in range(4):
                    op = input("Enter options ")
                    options.append(op)
                answers.append(int(input("Enter Answer : ")))
                q_a[question] = options[0:4]
                options.clear()
                print("Question Done \n")
                return n

        elif(yes!=1):
            print("Test Closed")
            return None


    # DISPLAYING QUESTIONS

    number_of_q = Test()
    if(number_of_q != None):
        options2 = []
        def Test_Start():
            for i in range(number_of_q):
                print(questions[i],"\n")
                for j in q_a[questions[i]]:
                         print("Option) ",j)
                print("\n")

        if(number_of_q != None):
            Test_Start()

        # CONVERTING INTO .JSON

        DATA = dict()

        q_a
        opt = dict()
        optt = []


        for i in range(number_of_q):
            optt.append(q_a[questions[i]])
        opt["options"] = []


        def json():
            DATA["Questions"]=questions
            for i in range(number_of_q):
                DATA["Options"] = optt
                DATA["Answers"] = answers


        json()

        DATA

        import json
        f = open("EXAM_DATA.json", "w")
        json.dump(DATA, f)
        f.close()



        # STARTING THE TEST

        from tkinter import *
        from tkinter import messagebox as mb
        import json
        class Quiz:
            def __init__(self):
                self.q_no=0
                self.display_title()
                self.display_question()
                self.opt_selected=IntVar()
                self.opts=self.radio_buttons()
                self.display_options()
                self.buttons()
                self.data_size=len(question)
                self.correct=0
            def display_result(self):
                wrong_count = self.data_size - self.correct
                correct = f"Correct: {self.correct}"
                wrong = f"Wrong: {wrong_count}"
                score = int(self.correct / self.data_size * 100)
                result = f"Score: {score}%"
                mb.showinfo("Result", f"{result}\n{correct}\n{wrong}")
            def check_ans(self, q_no):
                if self.opt_selected.get() == answer[q_no]:
                    return True
            def next_btn(self):
                if self.check_ans(self.q_no):
                    self.correct += 1
                self.q_no += 1
                if self.q_no==self.data_size:	
                    self.display_result()
                    gui.destroy()
                else:
                    self.display_question()
                    self.display_options()
            def buttons(self):
                next_button = Button(gui, text="Next",command=self.next_btn,
                width=10,bg="blue",fg="white",font=("ariel",16,"bold"))
                next_button.place(x=350,y=380)
                quit_button = Button(gui, text="Quit", command=gui.destroy,
                width=5,bg="black", fg="white",font=("ariel",16," bold"))
                quit_button.place(x=700,y=50)
            def display_options(self):
                val=0
                self.opt_selected.set(0)
                for option in options[self.q_no]:
                    self.opts[val]['text']=option
                    val+=1
            def display_question(self):
                q_no = Label(gui, text=question[self.q_no], width=60,
                font=( 'ariel' ,16, 'bold' ), anchor= 'w' )
                q_no.place(x=70, y=100)
            def display_title(self):
                title = Label(gui, text="INTELLIGENT PROCTOR",
                width=50, bg="Red",fg="white", font=("ariel", 20, "bold"))
                title.place(x=0, y=2)

            def radio_buttons(self):

                # initialize the list with an empty list of options
                q_list = []

                # position of the first option
                y_pos = 150

                # adding the options to the list
                while len(q_list) < 4:


                    radio_btn = Radiobutton(gui,text=" ",variable=self.opt_selected,
                    value = len(q_list)+1,font = ("ariel",14))


                    q_list.append(radio_btn)


                    radio_btn.place(x = 100, y = y_pos)


                    y_pos += 40


                return q_list
        gui = Tk()
        gui.geometry("800x450")
        gui.title("MCQ")
        with open('EXAM_DATA.json') as f:
            data = json.load(f)
        question = (data['Questions'])
        options = (data['Options'])
        answer = (data[ 'Answers'])





        quiz = Quiz()
        gui.mainloop()
    else:
        print("Invalid Data")
# Out:
# Authentication Successfull for  SONU
# Do you want to create new test ?
#
#    Enter 1 for yes:  1
# Enter Number Of Questions:  1
# Enter The Question:  name?
# Enter options d
# Enter options m
# Enter options n
# Enter options sonu
# Enter Answer : 4
# Question Done
#
# name?
#
# Option)  d
# Option)  m
# Option)  n
# Option)  sonu
